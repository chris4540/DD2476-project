# %%
import pandas as pd

# %%
annotate = pd.read_csv("userA-annotate.csv", header=None)
annotate.columns = ["name", "rel"]
annotate = annotate.set_index("name")

# %%
rel_dict = annotate["rel"].to_dict()

# %%
0 click

# %%
df0 = pd.read_csv("userA-0click.csv", header=None, index_col=0)

# %%
df0 = df0.drop([1], axis=1)

# %%
df0.columns = ['name']

# %%
df0["rel"] = df0["name"].map(rel_dict, na_action='ignore')

# %%
df0.to_csv("userA-0click.csv", header=False)

# %%
df0
# Out:
#                           name  rel
# 0
# 0                        Javas    0
# 1                        Javor    0
# 2                         Java    3
# 3                        Javea    0
# 4                          Jäv    0
# 5                        Jäven    0
# 6                    Javatiger    2
# 7                     Lac Java    0
# 8                   Mali Javor    0
# 9                 Veliki Javor    0
# 10                   Java Park    0
# 11                Java Servlet    0
# 12         Java (programspråk)    0
# 13                  Javor Brdo    0
# 14               Javor Planina    0
# 15              Javad Kazemian    0
# 16                 Javea (ort)    0
# 17               Javor (ravin)    0
# 18                         JAV    0
# 19              Javea (kommun)    0
# 20     Java (olika betydelser)    1
# 21                 Oštri Javor    0
# 22                Debeli Javor    0
# 23          Listrodromus javae    0
# 24               Gryon javense    0
# ...

# %% [markdown]
# 1 click

# %%
df1 = pd.read_csv("userA-1click.csv", header=None, index_col=0)

# %%
df1 = df1.drop([1], axis=1)

# %%
df1.columns = ['name']

# %%
df1["rel"] = df1["name"].map(rel_dict, na_action='ignore')

# %%
rel_dict['Javanesiska'] = 2
rel_dict['Yogyakarta (region)'] = 2
rel_dict['Kungariket Medang'] = 2
rel_dict['Majapahitriket'] = 2
rel_dict['Borobudur'] = 2
rel_dict['Singhasari'] = 2
rel_dict['Melati van Java'] = 0
rel_dict['Thripobius javae'] = 0
rel_dict['Jordbävningen utanför Java i maj 2006']  = 0
rel_dict['Seyed Javad Miri'] = 0

# %%
df1["rel"] = df1["name"].map(rel_dict, na_action='ignore')

# %%
df1.to_csv("userA-1click.csv", header=False)

# %% [markdown]
# 2 click

# %%
df2 = pd.read_csv("userA-2click.csv", header=None, index_col=0)

# %%
df2 = df2.drop([1], axis=1)
df2.columns = ['name']

# %%
df2["rel"] = df2["name"].map(rel_dict, na_action='ignore')

# %%
df2
# Out:
#                           name  rel
# 0
# 0                    Javatiger    2
# 1                         Java    3
# 2                        Javas    0
# 3                        Javor    0
# 4                          Jäv    0
# 5                        Javea    0
# 6                        Jäven    0
# 7                 Java Servlet    0
# 8                     Lac Java    0
# 9          Java (programspråk)    0
# 10                  Mali Javor    0
# 11                Veliki Javor    0
# 12                   Java Park    0
# 13                  Javor Brdo    0
# 14              Eupelmus javae    0
# 15              Javad Kazemian    0
# 16               Javor Planina    0
# 17          Neobrachista javae    0
# 18                 Javea (ort)    0
# 19     Java (olika betydelser)    1
# 20         Philotrypesis javae    0
# 21               Javor (ravin)    0
# 22              Javea (kommun)    0
# 23                         JAV    0
# 24                 Oštri Javor    0
# ...

# %%
df2.to_csv("userA-2click.csv", header=False)

# %% [markdown]
# 5 clicks

# %%
df5 = pd.read_csv("userA-5click.csv", header=None, index_col=0)

# %%
df5 = df5.drop([1], axis=1)
df5.columns = ['name']

# %%
df5["rel"] = df5["name"].map(rel_dict, na_action='ignore')

# %%
df5
# Out:
#                             name  rel
# 0
# 0                     Sundariket  NaN
# 1                 Majapahitriket  2.0
# 2                           Java  3.0
# 3                      Javatiger  2.0
# 4   Mongolernas invasion av Java  2.0
# 5                     Singhasari  2.0
# 6                          Javas  0.0
# 7                          Javor  0.0
# 8                            Jäv  0.0
# 9                          Javea  0.0
# 10                         Jäven  0.0
# 11           Java (programspråk)  0.0
# 12                      Lac Java  0.0
# 13       Java (olika betydelser)  1.0
# 14                  Java Servlet  0.0
# 15                    Mali Javor  0.0
# 16                  Veliki Javor  0.0
# 17                     Java Park  0.0
# 18                    Javor Brdo  0.0
# 19                Javad Kazemian  0.0
# 20                 Javor Planina  0.0
# 21                   Javea (ort)  0.0
# 22                 Javor (ravin)  0.0
# ...

# %%
rel_dict['Sundariket'] = 2

# %%
df5["rel"] = df5["name"].map(rel_dict, na_action='ignore')

# %%
df5.to_csv("userA-5click.csv", header=False)

# %% [markdown]
# 10 clicks

# %%
df10 = pd.read_csv("userA-10click.csv", header=None, index_col=0)

# %%
df10 = df10.drop([1], axis=1)

# %%
df10.columns = ['name']

# %%
df10['rel'] = df10['name'].map(rel_dict, na_action='ignore')

# %%
df10.to_csv("userA-10click.csv", header=False)
